# %% [markdown]
# # Bibliotecas
#
# https://pandas.pydata.org

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Criando data frame a partir de array usando Numpy

# %%
data = np.array(([1,2],[10,15]))
data
# Out:
# array([[ 1,  2],
#        [10, 15]])

# %%
df = pd.DataFrame(data, columns=['Preço', 'Unidades'])

# %%
df
# Out:
#    Preço  Unidades
# 0      1         2
# 1     10        15

# %% [markdown]
# # Criação de dataframes a partir de dicionários

# %%
# Criando um dicionário usando listas

# %%
states = ["PE", "PB", "SP", "RJ"]
population = [927800, 12330000, 16460000, 6851000]

# %%
dict_state = {"Estado": states, "Populacao": population}

# %%
df_population = pd.DataFrame(dict_state)

# %%
df_population
# Out:
#   Estado  Populacao
# 0     PE     927800
# 1     PB   12330000
# 2     SP   16460000
# 3     RJ    6851000

# %%
# Criando um dicionário do zero

# %%
data = {
    "Nome": ["Alice", "Bruno", "Carlos", "David"],
    "Idade": [25, 30, 22, 27],
    "Cidade": ["São Paulo", "Rio de Janeiro", "Belo Horizonte", "Salvador"]
}

# %%
df_pessoas = pd.DataFrame(data)

# %%
df_pessoas
# Out:
#      Nome  Idade          Cidade
# 0   Alice     25       São Paulo
# 1   Bruno     30  Rio de Janeiro
# 2  Carlos     22  Belo Horizonte
# 3   David     27        Salvador

# %% [markdown]
# # Criação de data frame a partir de um arquivo .csv

# %%
# !git clone https://github.com/eron93br/t2i-python-ad.git
# Out:
# Cloning into 't2i-python-ad'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 21 (delta 5), reused 12 (delta 5), pack-reused 0
# Receiving objects: 100% (21/21), 142.59 KiB | 5.09 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %% [markdown]
# Os arquivos do excel "aula2" estão no drive na pasta 2. Introdução à Análise de Dados

# %%
df = pd.read_csv('/content/aula2 - Sheet1.csv')

# %%
df
# Out:
#     Produto  Quantidade  Valor
# 0   tesoura           3  10.00
# 1    xícara           5  15.00
# 2  mousepad        3131  12.43

# %%
df2 = pd.read_excel("/content/aula2.xlsx")

# %%
df2
# Out:
#     Produto  Quantidade  Valor
# 0   tesoura           3  10.00
# 1    xícara           5  15.00
# 2  mousepad        3131  12.43

# %% [markdown]
# # Display de DataFrames

# %%
df = pd.read_csv("/content/t2i-python-ad/data/sales.csv")

# %% [markdown]
# # Colunas: df.columns

# %%
# esse método retorna uma lista com todas as colunas daquele dataframe
df.columns

# %% [markdown]
# # Coluna e tipo de dado de cada coluna: df.types

# %%
# esse método retorna além da coluna o tipo de dado que está ali
df.dtypes

# %% [markdown]
# # Coluna, tipo de item, lista, quantidade de linhas não nulas: df.info()

# %%
# retorna uma inspeção rápida que a coluna, o tipo de dado da coluna e lista
# a quantidade de linhas não nulas; e uma lista dos tipos dos dados
df.info()

# %% [markdown]
# # Primeiras N linhas: df.head(n)

# %%
# esse método HEAD mostra as N primeiras linhas
df.head(5)

# %% [markdown]
# # Últimas N linhas: df.tail(n)

# %%
# esse método TAIL mostra as N últimas linhas
df.tail(5)

# %% [markdown]
# # Outro dataframe só que com separador diferente

# %%
df = pd.read_csv("/content/t2i-python-ad/data/reclamacoes.csv", sep=";", encoding="latin-1")

# %%
df.head(3)
# Out:
#     Ano Trimestre         Categoria          Tipo CNPJ IF  \
# 0  2021        1º  Grupo Secundário  Conglomerado
# 1  2021        1º  Grupo Secundário  Conglomerado
# 2  2021        1º  Grupo Secundário  Conglomerado
#
#       Instituição financeira  \
# 0  ABC-BRASIL (conglomerado)
# 1  ABC-BRASIL (conglomerado)
# 2  ABC-BRASIL (conglomerado)
#
#                                       Irregularidade  \
# 0  Abertura de conta de depósito com documentação...
# 1  Abertura de conta de pagamento sem documentaçã...
# 2  Inclusão de dados incorretos no CCS (Cadastro ...
#
#    Quantidade de reclamações reguladas procedentes  \
# 0                                                0
# 1                                                0
# 2                                                1
#
#    Quantidade de reclamações reguladas - outras  \
# 0                                             1
# 1                                             1
# 2                                             0
#
# ...

# %% [markdown]
# # Quantidade de linhas e colunas: df.shape

# %%
# shape, mostra a quantidade de (linhas, colunas) de um dataframe
df.shape
# Out:
# (10363, 12)

# %% [markdown]
# # Nome das colunas: df.columns

# %%
# columns, lista dos nomes das colunas
df.columns
# Out:
# Index(['Ano', 'Trimestre', 'Categoria', 'Tipo', 'CNPJ IF',
#        'Instituição financeira', 'Irregularidade',
#        'Quantidade de reclamações reguladas procedentes',
#        'Quantidade de reclamações reguladas - outras',
#        'Quantidade de reclamações não reguladas',
#        'Quantidade total de reclamações', 'Unnamed: 11'],
#       dtype='object')

# %% [markdown]
# # Informações estatísticas dos dados: df.describe()

# %%
# describe, passa uma informação estatística dos dados
df.describe()
# Out:
#            Ano  Quantidade de reclamações reguladas procedentes  \
# count  10363.0                                     10363.000000
# mean    2021.0                                         8.472643
# std        0.0                                        60.298405
# min     2021.0                                         0.000000
# 25%     2021.0                                         0.000000
# 50%     2021.0                                         0.000000
# 75%     2021.0                                         3.000000
# max     2021.0                                      4217.000000
#
#        Quantidade de reclamações reguladas - outras  \
# count                                  10363.000000
# mean                                      10.710412
# std                                       36.509791
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        1.000000
# ...

# %%
# info, informações gerais
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10363 entries, 0 to 10362
# Data columns (total 12 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Ano                                              10363 non-null  int64
#  1   Trimestre                                        10363 non-null  object
#  2   Categoria                                        10363 non-null  object
#  3   Tipo                                             10363 non-null  object
#  4   CNPJ IF                                          10363 non-null  object
#  5   Instituição financeira                           10363 non-null  object
#  6   Irregularidade                                   10363 non-null  object
#  7   Quantidade de reclamações reguladas procedentes  10363 non-null  int64
#  8   Quantidade de reclamações reguladas - outras     10363 non-null  int64
# ...

# %%
# unique, lista todos os dados daquela coluna
df['Irregularidade'].unique()

# %%
# value_counts, conta os valores daquela coluna
df['Irregularidade'].value_counts()
# Out:
# Irregularidade
# Irregularidades relacionadas ao Sistema de Informações de Crédito do Banco Central (SCR)                   237
# Insatisfação com a resposta recebida da instituição financeira referente à reclamação registrada no BCB    232
# Renegociação de dívida (exceto cartão de crédito)                                                          227
# Reclamações relacionadas a assuntos diversos                                                               216
# Insatisfação com o atendimento prestado pelo SAC ou Central de Relacionamento                              213
#                                                                                                           ...
# Restrição à realização de portabilidade de operações de crédito relativas a pessoas jurídicas                1
# Operações de entidades não fiscalizadas pelo Banco Central                                                   1
# ...

# %%
df['Trimestre'].value_counts()
# Out:
# Trimestre
# 4º    3090
# 3º    2515
# 2º    2411
# 1º    2347
# Name: count, dtype: int64

# %%
# listar todas as informações daquela coluna específica
df['Instituição financeira']
# tem que ser o nome exato da coluna
# Out:
# 0          ABC-BRASIL (conglomerado)
# 1          ABC-BRASIL (conglomerado)
# 2          ABC-BRASIL (conglomerado)
# 3          ABC-BRASIL (conglomerado)
# 4          ABC-BRASIL (conglomerado)
#                     ...
# 10358    YAMAHA MOTOR (conglomerado)
# 10359    YAMAHA MOTOR (conglomerado)
# 10360    YAMAHA MOTOR (conglomerado)
# 10361    YAMAHA MOTOR (conglomerado)
# 10362    YAMAHA MOTOR (conglomerado)
# Name: Instituição financeira, Length: 10363, dtype: object

# %%
# também posso fazer df.NOMEDACOLUNA pra listar direto a coluna
df.Ano
# só que se for uma coluna do tipo "Intituição financeira" vai dar erro
# então tem que ser da forma acima
# Out:
# 0        2021
# 1        2021
# 2        2021
# 3        2021
# 4        2021
#          ...
# 10358    2021
# 10359    2021
# 10360    2021
# 10361    2021
# 10362    2021
# Name: Ano, Length: 10363, dtype: int64

# %% [markdown]
# # Pegar linha da posição n: iloc[n]

# %%
# iloc[n], pegar a linha daquela posição
df.iloc[0]
# primeira linha
# Out:
# Ano                                                                                             2021
# Trimestre                                                                                         1º
# Categoria                                                                           Grupo Secundário
# Tipo                                                                                    Conglomerado
# CNPJ IF
# Instituição financeira                                                     ABC-BRASIL (conglomerado)
# Irregularidade                                     Abertura de conta de depósito com documentação...
# Quantidade de reclamações reguladas procedentes                                                    0
# Quantidade de reclamações reguladas - outras                                                       1
# Quantidade de reclamações não reguladas                                                            0
# ...

# %%
# iloc[n:m], pega as linhas da posição n até m-1
df.iloc[0:3]
# Out:
#     Ano Trimestre         Categoria          Tipo CNPJ IF  \
# 0  2021        1º  Grupo Secundário  Conglomerado
# 1  2021        1º  Grupo Secundário  Conglomerado
# 2  2021        1º  Grupo Secundário  Conglomerado
#
#       Instituição financeira  \
# 0  ABC-BRASIL (conglomerado)
# 1  ABC-BRASIL (conglomerado)
# 2  ABC-BRASIL (conglomerado)
#
#                                       Irregularidade  \
# 0  Abertura de conta de depósito com documentação...
# 1  Abertura de conta de pagamento sem documentaçã...
# 2  Inclusão de dados incorretos no CCS (Cadastro ...
#
#    Quantidade de reclamações reguladas procedentes  \
# 0                                                0
# 1                                                0
# 2                                                1
#
#    Quantidade de reclamações reguladas - outras  \
# 0                                             1
# 1                                             1
# 2                                             0
#
# ...

# %%
# você pode jogar isso numa variável, e "cortar" uma tabela
a = df.iloc[0:3]
a
# Out:
#     Ano Trimestre         Categoria          Tipo CNPJ IF  \
# 0  2021        1º  Grupo Secundário  Conglomerado
# 1  2021        1º  Grupo Secundário  Conglomerado
# 2  2021        1º  Grupo Secundário  Conglomerado
#
#       Instituição financeira  \
# 0  ABC-BRASIL (conglomerado)
# 1  ABC-BRASIL (conglomerado)
# 2  ABC-BRASIL (conglomerado)
#
#                                       Irregularidade  \
# 0  Abertura de conta de depósito com documentação...
# 1  Abertura de conta de pagamento sem documentaçã...
# 2  Inclusão de dados incorretos no CCS (Cadastro ...
#
#    Quantidade de reclamações reguladas procedentes  \
# 0                                                0
# 1                                                0
# 2                                                1
#
#    Quantidade de reclamações reguladas - outras  \
# 0                                             1
# 1                                             1
# 2                                             0
#
# ...

# %% [markdown]
# # Renomear: rename

# %%
# rename, alterar nome das colunas
df.rename(columns={'Instituição financeira': 'InstituicaoFinanceira'})
# esse de cima só vai renomear mas não tá jogando em variável nenhuma
df.rename(columns={'Instituição financeira': 'InstituicaoFinanceira'}, inplace=True)
# com o inplace ele tá escrevendo na variável original
# outra opção seria a abaixo
# df = df.rename(columns={'Instituição financeira': 'InstituicaoFinanceira'})

# %%
df['InstituicaoFinanceira']
# Out:
# 0          ABC-BRASIL (conglomerado)
# 1          ABC-BRASIL (conglomerado)
# 2          ABC-BRASIL (conglomerado)
# 3          ABC-BRASIL (conglomerado)
# 4          ABC-BRASIL (conglomerado)
#                     ...
# 10358    YAMAHA MOTOR (conglomerado)
# 10359    YAMAHA MOTOR (conglomerado)
# 10360    YAMAHA MOTOR (conglomerado)
# 10361    YAMAHA MOTOR (conglomerado)
# 10362    YAMAHA MOTOR (conglomerado)
# Name: InstituicaoFinanceira, Length: 10363, dtype: object

# %% [markdown]
# # Exclusão: df.drop(o que apagar,axis=N)

# %%
# drop com axis=1 apaga as colunas
df2 = df.drop(['CNPJ IF', 'Unnamed: 11'], axis=1)

# %%
df2.head(3)

# %%
# drop com axis=0 apaga as linhas daqueles índices
df3 = df.drop([0, 1, 2], axis=0)

# %%
df3.head(3)

# %% [markdown]
# # Filtragem de dados:unique()

# %%
df2['InstituicaoFinanceira'].value_counts()
# Out:
# InstituicaoFinanceira
# SANTANDER (conglomerado)                    448
# BRADESCO (conglomerado)                     432
# ITAU (conglomerado)                         432
# CAIXA ECONÔMICA FEDERAL (conglomerado)      428
# BB (conglomerado)                           424
#                                            ...
# BANCO KOMATSU DO BRASIL S.A.                  1
# BANCO RABOBANK INTERNATIONAL BRASIL S.A.      1
# BANCO RIBEIRAO PRETO S.A.                     1
# BNY MELLON (conglomerado)                     1
# BANCO DE LA NACION ARGENTINA                  1
# Name: count, Length: 166, dtype: int64

# %%
df2_santander = df2[df2['InstituicaoFinanceira'] == 'SANTANDER (conglomerado)']

# %%
df2_santander.head(3)

# %%
# fazendo isso pra verificar se naquela coluna tem apenas o foi filtrado
df2_santander['InstituicaoFinanceira'].unique()
# Out:
# array(['SANTANDER (conglomerado)'], dtype=object)

# %% [markdown]
# # Group by

# %%
# 'Quantidade de reclamações reguladas procedentes'

# %%
df.head(3)
# Out:
#     Ano Trimestre         Categoria          Tipo CNPJ IF  \
# 0  2021        1º  Grupo Secundário  Conglomerado
# 1  2021        1º  Grupo Secundário  Conglomerado
# 2  2021        1º  Grupo Secundário  Conglomerado
#
#        InstituicaoFinanceira  \
# 0  ABC-BRASIL (conglomerado)
# 1  ABC-BRASIL (conglomerado)
# 2  ABC-BRASIL (conglomerado)
#
#                                       Irregularidade  \
# 0  Abertura de conta de depósito com documentação...
# 1  Abertura de conta de pagamento sem documentaçã...
# 2  Inclusão de dados incorretos no CCS (Cadastro ...
#
#    Quantidade de reclamações reguladas procedentes  \
# 0                                                0
# 1                                                0
# 2                                                1
#
#    Quantidade de reclamações reguladas - outras  \
# 0                                             1
# 1                                             1
# 2                                             0
#
# ...

# %%
# groupby(coluna que vai ser agrupado)[filtrar as colunas que eu quero que apareçam].sum() pra somar
rpc = df.groupby('InstituicaoFinanceira')['Quantidade de reclamações reguladas procedentes'].sum()

# %%
# sort_values(ascending= TRUE para mostrar do menor para o maior, FALSE para
# mostrar do maior para o menor).head(5) para mostrar apenas os 5 primeiros
top_rpc =  rpc.sort_values(ascending=False).head(5)

# %%
top_rpc
# Out:
# InstituicaoFinanceira
# CAIXA ECONÔMICA FEDERAL (conglomerado)    15772
# C6 BANK (conglomerado)                    12707
# BRADESCO (conglomerado)                   10905
# SANTANDER (conglomerado)                   6080
# ITAU (conglomerado)                        5615
# Name: Quantidade de reclamações reguladas procedentes, dtype: int64

# %% [markdown]
# # Pivot Table:;

# %%
df = pd.DataFrame({"A": ["foo","foo","foo","foo","foo","bar","bar","bar","bar"],
                   "B": ["one","one","one","two","two","one","one","two","two"],
                   "C": ["small","large","large","small","small","large","small","small","large"],
                   "D": [1,2,2,3,3,4,5,6,7],
                   "E": [2,4,5,5,6,6,8,9,9]})

# %%
df
# Out:
#      A    B      C  D  E
# 0  foo  one  small  1  2
# 1  foo  one  large  2  4
# 2  foo  one  large  2  5
# 3  foo  two  small  3  5
# 4  foo  two  small  3  6
# 5  bar  one  large  4  6
# 6  bar  one  small  5  8
# 7  bar  two  small  6  9
# 8  bar  two  large  7  9

# %%
table = pd.pivot_table(df,values='D',index=['A','B'], columns=['C'],aggfunc='sum')

# %%
table
# Out:
# C        large  small
# A   B
# bar one    4.0    5.0
#     two    7.0    6.0
# foo one    4.0    1.0
#     two    NaN    6.0

# %%
df.columns
# Out:
# Index(['Ano', 'Trimestre', 'Categoria', 'Tipo', 'CNPJ IF',
#        'Instituição financeira', 'Irregularidade',
#        'Quantidade de reclamações reguladas procedentes',
#        'Quantidade de reclamações reguladas - outras',
#        'Quantidade de reclamações não reguladas',
#        'Quantidade total de reclamações', 'Unnamed: 11'],
#       dtype='object')

# %%
tabela = pd.pivot_table(df, 'Quantidade total de reclamações', 'Trimestre','Tipo',aggfunc='sum')

# %%
tabela
# Out:
# Tipo       Banco/financeira  Conglomerado
# Trimestre
# 1º                     1815         69592
# 2º                     2133         68159
# 3º                     2212         64288
# 4º                     3524         56790

# %% [markdown]
# # Lambda functions

# %%
data = {"Produto": ["A","B","C","D"],
        "Preço": [100,200,150,120],
        "Categoria": ["Eletrônicos","Roupas","Eletrônicos","Roupas"]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Produto  Preço    Categoria
# 0       A    100  Eletrônicos
# 1       B    200       Roupas
# 2       C    150  Eletrônicos
# 3       D    120       Roupas

# %% [markdown]
# Nova regra: aumentar o preço em 10%

# %%
df['Preço'] = df['Preço'].apply(lambda x: x*1.1)

# %%
df
# Out:
#   Produto  Preço    Categoria
# 0       A  110.0  Eletrônicos
# 1       B  220.0       Roupas
# 2       C  165.0  Eletrônicos
# 3       D  132.0       Roupas

# %% [markdown]
# Nova regra: colocar nova coluna com Lucro de 4%

# %%
df['Lucro'] = df['Preço']*0.04

# %%
df
# Out:
#   Produto  Preço    Categoria  Lucro
# 0       A  110.0  Eletrônicos   4.40
# 1       B  220.0       Roupas   8.80
# 2       C  165.0  Eletrônicos   6.60
# 3       D  132.0       Roupas   5.28

# %% [markdown]
# Indo para o dataset sales

# %%
sales = pd.read_csv('/content/t2i-python-ad/data/sales.csv')

# %%
sales.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %%
sales.shape
# Out:
# (1000, 17)

# %%
def ajuste_df(input):
  if (input == 'Male'):
    return 0
  elif (input == 'Female'):
    return 1

# %%
sales['Gender'] = sales['Gender'].apply(lambda x: ajuste_df(x))

# %%
sales.head(5)
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member       1
# 1  226-31-3081      C  Naypyitaw        Normal       1
# 2  631-41-3108      A     Yangon        Normal       0
# 3  123-19-1176      A     Yangon        Member       0
# 4  373-73-7910      A     Yangon        Normal       0
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# # Códigos úteis

# %% [markdown]
# Leitura e Escrita de Dados:
#
# - `pd.read_csv()`: Para ler dados de um arquivo CSV em um DataFrame.
# - `pd.read_excel()`: Para ler dados de uma planilha Excel em um DataFrame.
# - `pd.read_sql()`: Para ler dados de um banco de dados SQL em um DataFrame.
# - `df.to_csv()`: Para salvar um DataFrame em um arquivo CSV.
# - `df.to_excel()`: Para salvar um DataFrame em um arquivo Excel.
#
# Estruturação e Inspeção de Dados:
#
# - `pd.DataFrame()`: Cria um DataFrame a partir de dados em Python (listas, dicionários, arrays, etc.).
#
# - `df.head()`, `df.tail()`: Exibe as primeiras ou últimas linhas do DataFrame.
#
# - `df.shape`: Retorna a dimensão (número de linhas e colunas) do DataFrame.
#
# - `df.info()`: Retorna informações sobre o DataFrame, incluindo tipos de dados e valores não nulos.
#
# - `df.describe()`: Gera estatísticas descritivas para as colunas numéricas do DataFrame.
#
# Seleção e Indexação:
#
# - `df[column_name]` ou `df.loc[:, column_name]`: Seleciona uma coluna do DataFrame.
#
# - `df.iloc[row_index]`: Seleciona uma linha do DataFrame pelo índice inteiro.
# - `df.loc[row_label]`: Seleciona uma linha do DataFrame pelo rótulo do índice.
# - `df.iloc[start_row:end_row, start_col:end_col]`: Seleciona um subconjunto do DataFrame usando índices inteiros.
# - `df.loc[start_label:end_label, start_col:end_col]`: Seleciona um subconjunto do DataFrame usando rótulos de índice.
#
# Filtragem e Consultas:
#
# - `df[df['column'] > value]`: Filtra o DataFrame com base em uma condição.
# - `df.query('condition')`: Filtra o DataFrame usando uma string de consulta.
# - `df.isnull(), df.notnull()`: Verifica quais valores são nulos ou não nulos.
# - `df[df['column'].isin([value1, value2])]`: Filtra o DataFrame com base em valores específicos.
#
# Operações de Agregação:
#
# - `df.groupby()`: Agrupa o DataFrame com base em uma ou mais colunas.
# - `grouped_df.agg()`: Executa operações de agregação em grupos de dados.
# - `df.sum(), df.mean(), df.min(), df.max()`: Calcula a soma, média, valor mínimo e valor máximo das colunas numéricas.
#
# Operações de Limpeza:
#
# - `df.dropna()`: Remove linhas com valores nulos do DataFrame.
# - `df.fillna(value)`: Preenche valores nulos com um valor específico.
# - `df.drop()`: Remove colunas ou linhas do DataFrame.
